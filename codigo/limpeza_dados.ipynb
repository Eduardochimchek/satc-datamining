# %% [markdown]
# # DataMining - Projeto SATC2030
#
# #### Integrantes
# - Eduardo Chimchek Jeronimo
# - Higor Rufino Librelato
# - Lucas Siqueira Sosa
# - Rafael da Silva Dagostim
# - Yago Carvalho da Paixão

# %% [markdown]
# ## Etapa 3 - Limpeza dos dados

# %% [markdown]
# ### Importando Dados

# %%
import pandas as pd
import numpy as np

# %%
dadosParada = pd.read_excel('../data/dados.xlsx')
dadosParada.head()
# Out:
#    Empresa  Filial       Data Hora Inicio Hora Término Total Horas (hh:mm:ss)  \
# 0      1.0     1.0 2023-03-01    17:57:00     18:00:00               00:03:00
# 1      1.0     1.0 2023-03-01    17:55:00     18:00:00               00:05:00
# 2      1.0     1.0 2023-03-01    17:50:00     17:53:24               00:03:24
# 3      1.0     1.0 2023-03-01    17:46:00     18:00:00               00:14:00
# 4      1.0     1.0 2023-03-01    17:45:00     18:00:00               00:15:00
#
#    Total Horas  Número O.S. Tipo O.S.  Número O.P.  ...  Cód. Máquina  \
# 0         0.05          0.0       NaN          0.0  ...          14.0
# 1         0.08          0.0       NaN          0.0  ...          14.0
# 2         0.05     107378.0    Normal      19719.0  ...           NaN
# 3         0.23          0.0       NaN          0.0  ...          14.0
# 4         0.25          0.0       NaN          0.0  ...          14.0
#
#                  Máquina  Cód. Operador  Unnamed: 19 Cód. Serviço    Serviço  \
# 0  ORGANIZACAO E LIMPEZA          180.0   OPERADOR 1          NaN        NaN
# 1  ORGANIZACAO E LIMPEZA          121.0   OPERADOR 2          NaN        NaN
# 2                    NaN          150.0   OPERADOR 3          1.0  SEPARACAO
# 3  ORGANIZACAO E LIMPEZA          200.0   OPERADOR 4          NaN        NaN
# 4  ORGANIZACAO E LIMPEZA          199.0   OPERADOR 5          NaN        NaN
#
#    Cód. Centro Custo  Centro Custo    Usuário Data Última Alteração
# 0                NaN           NaN  PRODUCAO6            2023-03-07
# 1                NaN           NaN  PRODUCAO6            2023-03-07
# 2            80000.0  ALMOXARIFADO      ALMOX            2023-03-01
# 3                NaN           NaN  PRODUCAO6            2023-03-07
# 4                NaN           NaN  PRODUCAO6            2023-03-07
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Removendo Colunas Desnecessárias
# Como citado na parte 2 do documento do projeto, iremos retirar colunas que não apresentam uso dentro do projeto e do escopo escolhido.

# %%
dadosParada.columns
# Out:
# Index(['Empresa', 'Filial', 'Data', 'Hora Inicio', 'Hora Término',
#        'Total Horas (hh:mm:ss)', 'Total Horas', 'Número O.S.', 'Tipo O.S.',
#        'Número O.P.', 'Cód. Produto', 'Unnamed: 11', 'Qtde O.P.',
#        'Cód. Parada', 'Parada', 'Cód. Apara', 'Cód. Máquina', 'Máquina',
#        'Cód. Operador', 'Unnamed: 19', 'Cód. Serviço', 'Serviço',
#        'Cód. Centro Custo', 'Centro Custo', 'Usuário',
#        'Data Última Alteração'],
#       dtype='object')

# %%
dadosParada = dadosParada.drop(columns=['Empresa', 'Filial', 'Unnamed: 11', 'Unnamed: 19', 'Cód. Apara', 'Cód. Centro Custo', 'Centro Custo', 'Usuário', 'Data Última Alteração', 'Total Horas (hh:mm:ss)', 'Tipo O.S.'])
dadosParada.columns
# Out:
# Index(['Data', 'Hora Inicio', 'Hora Término', 'Total Horas', 'Número O.S.',
#        'Número O.P.', 'Cód. Produto', 'Qtde O.P.', 'Cód. Parada', 'Parada',
#        'Cód. Máquina', 'Máquina', 'Cód. Operador', 'Cód. Serviço', 'Serviço'],
#       dtype='object')

# %% [markdown]
# ### Formatando Nomes
# Para facilitar o entendimento do nome das colunas e do uso das mesmas ao longo do código, será feito uma formatação para remover caracteres especiais e espaçamentos além de padronizar tudo para minúscula e no formato snake_case

# %%
from unidecode import unidecode

def formatColumnName(column):
    newName = unidecode(column).lower()
    newName = newName.replace('.', '')
    newName = newName.replace(' ', '_')
    return newName

# %%
newNamesDict = dict()

for column in dadosParada.columns:
    newNamesDict[column] = formatColumnName(column)

newNamesDict
# Out:
# {'Data': 'data',
#  'Hora Inicio': 'hora_inicio',
#  'Hora Término': 'hora_termino',
#  'Total Horas': 'total_horas',
#  'Número O.S.': 'numero_os',
#  'Número O.P.': 'numero_op',
#  'Cód. Produto': 'cod_produto',
#  'Qtde O.P.': 'qtde_op',
#  'Cód. Parada': 'cod_parada',
#  'Parada': 'parada',
#  'Cód. Máquina': 'cod_maquina',
#  'Máquina': 'maquina',
#  'Cód. Operador': 'cod_operador',
#  'Cód. Serviço': 'cod_servico',
#  'Serviço': 'servico'}

# %%
dadosParada = dadosParada.rename(columns=newNamesDict)

dadosParada.head()
# Out:
#         data hora_inicio hora_termino  total_horas  numero_os  numero_op  \
# 0 2023-03-01    17:57:00     18:00:00         0.05        0.0        0.0
# 1 2023-03-01    17:55:00     18:00:00         0.08        0.0        0.0
# 2 2023-03-01    17:50:00     17:53:24         0.05   107378.0    19719.0
# 3 2023-03-01    17:46:00     18:00:00         0.23        0.0        0.0
# 4 2023-03-01    17:45:00     18:00:00         0.25        0.0        0.0
#
#    cod_produto  qtde_op  cod_parada  \
# 0          NaN      0.0         4.0
# 1          NaN      0.0         4.0
# 2       4387.0     50.0         9.0
# 3          NaN      0.0         9.0
# 4          NaN      0.0         9.0
#
#                                               parada  cod_maquina  \
# 0  PAUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL...         14.0
# 1  PAUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL...         14.0
# 2                                FINALIZACAO DE O.S.          NaN
# 3                                FINALIZACAO DE O.S.         14.0
# 4                                FINALIZACAO DE O.S.         14.0
#
#                  maquina  cod_operador  cod_servico    servico
# 0  ORGANIZACAO E LIMPEZA         180.0          NaN        NaN
# 1  ORGANIZACAO E LIMPEZA         121.0          NaN        NaN
# 2                    NaN         150.0          1.0  SEPARACAO
# 3  ORGANIZACAO E LIMPEZA         200.0          NaN        NaN
# 4  ORGANIZACAO E LIMPEZA         199.0          NaN        NaN

# %% [markdown]
# ### Verificando Tipo de Dados
# Precisamos verificar os tipos de dados que contem em cada coluna e com essa informação fazer o tratamento dos dados de forma adequada.

# %%
dadosParada['data'].unique()
# Out:
# array(['2023-03-01T00:00:00.000000000', '2023-03-02T00:00:00.000000000',
#        '2023-03-03T00:00:00.000000000', '2023-03-04T00:00:00.000000000',
#        '2023-03-06T00:00:00.000000000', '2023-03-07T00:00:00.000000000',
#        '2023-03-08T00:00:00.000000000', '2023-03-09T00:00:00.000000000',
#        '2023-03-10T00:00:00.000000000', '2023-03-11T00:00:00.000000000',
#        '2023-03-13T00:00:00.000000000', '2023-03-14T00:00:00.000000000',
#        '2023-03-15T00:00:00.000000000', '2023-03-16T00:00:00.000000000',
#        '2023-03-17T00:00:00.000000000', '2023-03-18T00:00:00.000000000',
#        '2023-03-20T00:00:00.000000000', '2023-03-21T00:00:00.000000000',
#        '2023-03-22T00:00:00.000000000', '2023-03-23T00:00:00.000000000',
#        '2023-03-24T00:00:00.000000000', '2023-03-25T00:00:00.000000000',
#        '2023-03-27T00:00:00.000000000', '2023-03-28T00:00:00.000000000',
#        '2023-03-29T00:00:00.000000000', '2023-03-30T00:00:00.000000000',
#        '2023-03-31T00:00:00.000000000',                           'NaT'],
#       dtype='datetime64[ns]')

# %%
dadosParada['hora_inicio'].unique()
# Out:
# array([datetime.time(17, 57), datetime.time(17, 55),
#        datetime.time(17, 50), datetime.time(17, 46),
#        datetime.time(17, 45), datetime.time(17, 44),
#        datetime.time(17, 40), datetime.time(17, 38),
#        datetime.time(17, 36), datetime.time(17, 35),
#        datetime.time(17, 31), datetime.time(17, 30),
#        datetime.time(17, 25), datetime.time(17, 22),
#        datetime.time(17, 16), datetime.time(17, 15),
#        datetime.time(17, 12), datetime.time(17, 10), datetime.time(17, 8),
#        datetime.time(17, 7), datetime.time(17, 5), datetime.time(17, 0),
#        datetime.time(16, 59), datetime.time(16, 58),
#        datetime.time(16, 56), datetime.time(16, 52),
#        datetime.time(16, 50), datetime.time(16, 48),
#        datetime.time(16, 47), datetime.time(16, 46),
#        datetime.time(16, 45), datetime.time(16, 44),
#        datetime.time(16, 43), datetime.time(16, 40),
#        datetime.time(16, 37), datetime.time(16, 35),
#        datetime.time(16, 32), datetime.time(16, 30),
#        datetime.time(16, 25), datetime.time(16, 23),
#        datetime.time(16, 20, 11), datetime.time(16, 20),
#        datetime.time(16, 19), datetime.time(16, 18),
#        datetime.time(16, 15), datetime.time(16, 10), datetime.time(16, 8),
#        datetime.time(16, 5), datetime.time(16, 4), datetime.time(16, 3),
#        datetime.time(16, 2), datetime.time(16, 0), datetime.time(15, 40),
#        datetime.time(15, 38), datetime.time(15, 37),
#        datetime.time(15, 35), datetime.time(15, 33),
#        datetime.time(15, 32), datetime.time(15, 30),
#        datetime.time(15, 28), datetime.time(15, 27),
#        datetime.time(15, 24), datetime.time(15, 22),
#        datetime.time(15, 20), datetime.time(15, 15),
#        datetime.time(15, 14), datetime.time(15, 10), datetime.time(15, 6),
#        datetime.time(15, 5), datetime.time(15, 4), datetime.time(15, 0),
#        datetime.time(14, 59), datetime.time(14, 55),
#        datetime.time(14, 52), datetime.time(14, 50),
#        datetime.time(14, 47), datetime.time(14, 45),
#        datetime.time(14, 44), datetime.time(14, 40),
#        datetime.time(14, 38), datetime.time(14, 37),
#        datetime.time(14, 36), datetime.time(14, 33),
#        datetime.time(14, 32), datetime.time(14, 30),
#        datetime.time(14, 28), datetime.time(14, 26),
#        datetime.time(14, 23), datetime.time(14, 21),
#        datetime.time(14, 20), datetime.time(14, 18),
#        datetime.time(14, 16), datetime.time(14, 15), datetime.time(14, 8),
#        datetime.time(14, 7), datetime.time(14, 6), datetime.time(14, 3),
#        datetime.time(14, 2), datetime.time(14, 0), datetime.time(13, 55),
#        datetime.time(13, 51), datetime.time(13, 50),
#        datetime.time(13, 49), datetime.time(13, 48),
#        datetime.time(13, 45), datetime.time(13, 44),
#        datetime.time(13, 40), datetime.time(13, 35),
#        datetime.time(13, 30), datetime.time(13, 29),
#        datetime.time(13, 28), datetime.time(13, 27),
#        datetime.time(13, 25), datetime.time(13, 24),
#        datetime.time(13, 20), datetime.time(13, 18),
#        datetime.time(13, 15), datetime.time(13, 14),
#        datetime.time(13, 12), datetime.time(13, 10), datetime.time(13, 8),
#        datetime.time(13, 7), datetime.time(13, 4), datetime.time(13, 1),
#        datetime.time(13, 0), datetime.time(11, 57), datetime.time(11, 50),
#        datetime.time(11, 48), datetime.time(11, 45),
#        datetime.time(11, 40), datetime.time(11, 33),
#        datetime.time(11, 32), datetime.time(11, 30),
#        datetime.time(11, 29), datetime.time(11, 25),
#        datetime.time(11, 20), datetime.time(11, 18),
#        datetime.time(11, 15), datetime.time(11, 12),
#        datetime.time(11, 11), datetime.time(11, 10), datetime.time(11, 8),
#        datetime.time(11, 7), datetime.time(11, 5), datetime.time(11, 4),
#        datetime.time(11, 2), datetime.time(11, 0), datetime.time(10, 54),
#        datetime.time(10, 52), datetime.time(10, 50),
#        datetime.time(10, 45), datetime.time(10, 42),
#        datetime.time(10, 40), datetime.time(10, 38),
#        datetime.time(10, 37), datetime.time(10, 32),
#        datetime.time(10, 31), datetime.time(10, 30),
#        datetime.time(10, 27), datetime.time(10, 23),
#        datetime.time(10, 20), datetime.time(10, 18),
#        datetime.time(10, 17), datetime.time(10, 15),
#        datetime.time(10, 11), datetime.time(10, 10), datetime.time(10, 4),
#        datetime.time(10, 2), datetime.time(10, 0), datetime.time(9, 58),
#        datetime.time(9, 55), datetime.time(9, 51), datetime.time(9, 50),
#        datetime.time(9, 48), datetime.time(9, 47), datetime.time(9, 46),
#        datetime.time(9, 45), datetime.time(9, 27), datetime.time(9, 25),
#        datetime.time(9, 20), datetime.time(9, 15), datetime.time(9, 10),
#        datetime.time(9, 5), datetime.time(9, 0), datetime.time(8, 55),
#        datetime.time(8, 50), datetime.time(8, 47), datetime.time(8, 45),
#        datetime.time(8, 43), datetime.time(8, 36), datetime.time(8, 35),
#        datetime.time(8, 30), datetime.time(8, 28), datetime.time(8, 20),
#        datetime.time(8, 18), datetime.time(8, 15), datetime.time(8, 12),
#        datetime.time(8, 11), datetime.time(8, 10), datetime.time(8, 5),
#        datetime.time(8, 2), datetime.time(8, 1), datetime.time(8, 0),
#        datetime.time(17, 53), datetime.time(17, 52),
#        datetime.time(17, 49), datetime.time(17, 48),
#        datetime.time(17, 34), datetime.time(17, 32),
#        datetime.time(17, 26), datetime.time(17, 23),
#        datetime.time(17, 19), datetime.time(17, 18),
#        datetime.time(17, 14), datetime.time(17, 13), datetime.time(17, 9),
#        datetime.time(17, 4), datetime.time(17, 1), datetime.time(16, 57),
#        datetime.time(16, 55), datetime.time(16, 38),
#        datetime.time(16, 34), datetime.time(16, 31),
#        datetime.time(16, 26), datetime.time(16, 21),
#        datetime.time(16, 16), datetime.time(15, 45),
#        datetime.time(15, 43), datetime.time(15, 42),
#        datetime.time(15, 25), datetime.time(15, 13),
#        datetime.time(15, 12), datetime.time(15, 7), datetime.time(15, 1),
#        datetime.time(14, 54), datetime.time(14, 51),
#        datetime.time(14, 49, 3), datetime.time(14, 48),
#        datetime.time(14, 43), datetime.time(14, 41),
#        datetime.time(14, 35), datetime.time(14, 25),
#        datetime.time(14, 13), datetime.time(14, 12),
#        datetime.time(14, 10), datetime.time(14, 9), datetime.time(14, 5),
#        datetime.time(13, 52), datetime.time(13, 34),
#        datetime.time(13, 17), datetime.time(13, 11), datetime.time(13, 5),
#        datetime.time(13, 3), datetime.time(13, 2), datetime.time(12, 0),
#        datetime.time(11, 58), datetime.time(11, 52),
#        datetime.time(11, 46), datetime.time(11, 44),
#        datetime.time(11, 42), datetime.time(11, 39),
#        datetime.time(11, 35), datetime.time(11, 31),
#        datetime.time(11, 28), datetime.time(11, 22),
#        datetime.time(11, 19), datetime.time(11, 16),
#        datetime.time(11, 13), datetime.time(11, 1), datetime.time(10, 55),
#        datetime.time(10, 47), datetime.time(10, 36),
#        datetime.time(10, 34), datetime.time(10, 28),
#        datetime.time(10, 26), datetime.time(10, 22),
#        datetime.time(10, 21), datetime.time(10, 5), datetime.time(9, 23),
#        datetime.time(9, 21), datetime.time(9, 18), datetime.time(9, 16),
#        datetime.time(9, 1, 23), datetime.time(9, 1), datetime.time(8, 57),
#        datetime.time(8, 56), datetime.time(8, 52), datetime.time(8, 42),
#        datetime.time(8, 40), datetime.time(8, 33), datetime.time(8, 25),
#        datetime.time(8, 23), datetime.time(8, 21), datetime.time(8, 9),
#        datetime.time(16, 33), datetime.time(16, 29),
#        datetime.time(16, 28), datetime.time(16, 24),
#        datetime.time(16, 14), datetime.time(16, 13),
#        datetime.time(16, 12), datetime.time(16, 11),
#        datetime.time(15, 36), datetime.time(15, 29),
#        datetime.time(15, 26), datetime.time(15, 19), datetime.time(15, 2),
#        datetime.time(14, 56), datetime.time(14, 53),
#        datetime.time(14, 39), datetime.time(14, 11), datetime.time(14, 4),
#        datetime.time(13, 57), datetime.time(13, 46),
#        datetime.time(13, 39), datetime.time(13, 26),
#        datetime.time(13, 16), datetime.time(11, 56),
#        datetime.time(11, 55), datetime.time(11, 49),
#        datetime.time(11, 38), datetime.time(11, 37),
#        datetime.time(11, 26), datetime.time(11, 24),
#        datetime.time(11, 23), datetime.time(11, 3), datetime.time(10, 59),
#        datetime.time(10, 53), datetime.time(10, 33),
#        datetime.time(10, 29), datetime.time(10, 24), datetime.time(10, 6),
#        datetime.time(9, 57), datetime.time(9, 56), datetime.time(9, 35),
#        datetime.time(9, 28), datetime.time(9, 17), datetime.time(8, 59),
#        datetime.time(8, 53), datetime.time(8, 48), datetime.time(8, 46),
#        datetime.time(8, 41), datetime.time(8, 34), datetime.time(8, 31),
#        datetime.time(8, 29), datetime.time(8, 26), datetime.time(8, 24),
#        datetime.time(8, 22), datetime.time(8, 19), datetime.time(8, 16),
#        datetime.time(8, 4), datetime.time(8, 0, 33),
#        datetime.time(17, 51), datetime.time(17, 43),
#        datetime.time(17, 28), datetime.time(17, 20), datetime.time(17, 3),
#        datetime.time(17, 2), datetime.time(16, 53), datetime.time(16, 49),
#        datetime.time(16, 36), datetime.time(16, 27),
#        datetime.time(16, 17), datetime.time(16, 7), datetime.time(15, 34),
#        datetime.time(15, 21), datetime.time(15, 16),
#        datetime.time(15, 6, 26), datetime.time(14, 58),
#        datetime.time(14, 49), datetime.time(14, 42),
#        datetime.time(14, 31), datetime.time(13, 58),
#        datetime.time(13, 54), datetime.time(13, 43),
#        datetime.time(13, 37), datetime.time(13, 31),
#        datetime.time(13, 21), datetime.time(11, 21),
#        datetime.time(11, 17), datetime.time(11, 6), datetime.time(10, 56),
#        datetime.time(10, 51), datetime.time(10, 49),
#        datetime.time(10, 48), datetime.time(10, 46),
#        datetime.time(10, 44), datetime.time(10, 43),
#        datetime.time(10, 25), datetime.time(10, 16), datetime.time(9, 54),
#        datetime.time(9, 52), datetime.time(9, 24), datetime.time(9, 19),
#        datetime.time(9, 14), datetime.time(9, 13), datetime.time(9, 12),
#        datetime.time(9, 11, 11), datetime.time(9, 11),
#        datetime.time(9, 8), datetime.time(9, 7), datetime.time(8, 54),
#        datetime.time(8, 13), datetime.time(8, 8), datetime.time(8, 6),
#        datetime.time(17, 58), datetime.time(17, 54),
#        datetime.time(17, 41), datetime.time(17, 39),
#        datetime.time(17, 37), datetime.time(17, 27),
#        datetime.time(17, 11), datetime.time(17, 6), datetime.time(16, 42),
#        datetime.time(16, 41), datetime.time(16, 22), datetime.time(16, 6),
#        datetime.time(15, 46, 2), datetime.time(15, 41),
#        datetime.time(15, 8), datetime.time(14, 27), datetime.time(14, 22),
#        datetime.time(14, 14), datetime.time(13, 41),
#        datetime.time(13, 36), datetime.time(13, 32),
#        datetime.time(11, 54), datetime.time(11, 51),
#        datetime.time(11, 41), datetime.time(11, 27),
#        datetime.time(10, 41), datetime.time(10, 35),
#        datetime.time(10, 13), datetime.time(10, 10, 10),
#        datetime.time(10, 8), datetime.time(9, 59), datetime.time(9, 53),
#        datetime.time(9, 26), datetime.time(9, 3), datetime.time(8, 58),
#        datetime.time(8, 37), datetime.time(8, 14), datetime.time(17, 47),
#        datetime.time(17, 29), datetime.time(17, 17),
#        datetime.time(16, 54), datetime.time(16, 39), datetime.time(16, 9),
#        datetime.time(16, 1), datetime.time(15, 9), datetime.time(13, 59),
#        datetime.time(13, 56), datetime.time(13, 53),
#        datetime.time(13, 38), datetime.time(13, 22),
#        datetime.time(13, 13), datetime.time(11, 59),
#        datetime.time(11, 14), datetime.time(11, 9), datetime.time(10, 58),
#        datetime.time(10, 9), datetime.time(10, 3), datetime.time(9, 34),
#        datetime.time(9, 33), datetime.time(9, 32), datetime.time(9, 30),
#        datetime.time(9, 2), datetime.time(8, 51), datetime.time(8, 39),
#        datetime.time(8, 38), datetime.time(8, 32), datetime.time(8, 27),
#        datetime.time(15, 44), datetime.time(15, 39),
#        datetime.time(15, 11), datetime.time(14, 57),
#        datetime.time(14, 46), datetime.time(14, 34),
#        datetime.time(13, 23), datetime.time(9, 22), datetime.time(8, 49),
#        datetime.time(8, 7), datetime.time(16, 3, 17),
#        datetime.time(15, 23), datetime.time(15, 17),
#        datetime.time(14, 17), datetime.time(13, 19),
#        datetime.time(13, 0, 5), datetime.time(10, 57),
#        datetime.time(10, 39), datetime.time(9, 6), datetime.time(10, 19),
#        datetime.time(7, 16), datetime.time(7, 10), datetime.time(7, 0),
#        datetime.time(16, 51), datetime.time(15, 31),
#        datetime.time(15, 18), datetime.time(15, 3), datetime.time(14, 29),
#        datetime.time(14, 1), datetime.time(13, 33),
#        datetime.time(13, 0, 40), datetime.time(11, 36),
#        datetime.time(11, 34), datetime.time(10, 7), datetime.time(9, 49),
#        datetime.time(9, 9), datetime.time(17, 42), datetime.time(13, 42),
#        datetime.time(13, 6), datetime.time(10, 1), datetime.time(8, 17),
#        datetime.time(17, 24), datetime.time(11, 47),
#        datetime.time(10, 14), datetime.time(8, 44), datetime.time(18, 0),
#        datetime.time(17, 22, 20), datetime.time(11, 43),
#        datetime.time(10, 12), datetime.time(9, 36), datetime.time(9, 4),
#        datetime.time(13, 47), datetime.time(11, 53), datetime.time(9, 29),
#        datetime.time(7, 30), datetime.time(6, 40), datetime.time(6, 30),
#        datetime.time(6, 20), datetime.time(6, 10), datetime.time(6, 3),
#        datetime.time(6, 0), datetime.time(5, 53), datetime.time(5, 45),
#        datetime.time(7, 50), datetime.time(7, 22), datetime.time(18, 38),
#        datetime.time(18, 5), datetime.time(18, 1), datetime.time(17, 33),
#        datetime.time(15, 48), datetime.time(9, 40),
#        datetime.time(8, 26, 18), datetime.time(18, 10),
#        datetime.time(14, 24), datetime.time(14, 19), datetime.time(13, 9),
#        datetime.time(11, 28, 26), datetime.time(8, 3),
#        datetime.time(7, 25), datetime.time(7, 20), datetime.time(6, 45),
#        datetime.time(8, 0, 20), datetime.time(8, 0, 17),
#        datetime.time(4, 51), datetime.time(16, 4, 50),
#        datetime.time(7, 45), datetime.time(6, 55), datetime.time(6, 50),
#        datetime.time(17, 21), datetime.time(15, 46),
#        datetime.time(13, 8, 11), datetime.time(6, 57),
#        datetime.time(6, 5), datetime.time(11, 29, 32),
#        datetime.time(10, 30, 55), datetime.time(7, 5),
#        datetime.time(17, 56), datetime.time(16, 49, 27),
#        datetime.time(16, 35, 50), datetime.time(9, 45, 40),
#        datetime.time(7, 15), datetime.time(10, 25, 56),
#        datetime.time(7, 38), datetime.time(7, 27), nan], dtype=object)

# %%
dadosParada['hora_termino'].unique()
# Out:
# array([datetime.time(18, 0), datetime.time(17, 53, 24),
#        datetime.time(17, 47, 54), datetime.time(17, 41, 35),
#        datetime.time(17, 45), datetime.time(17, 35, 5),
#        datetime.time(17, 40), datetime.time(17, 25, 34),
#        datetime.time(17, 19, 43), datetime.time(17, 25),
#        datetime.time(17, 15), datetime.time(17, 7),
#        datetime.time(17, 1, 36), datetime.time(17, 5),
#        datetime.time(16, 58), datetime.time(16, 55, 39),
#        datetime.time(17, 55), datetime.time(17, 10),
#        datetime.time(16, 49), datetime.time(17, 0), datetime.time(17, 58),
#        datetime.time(16, 46, 52), datetime.time(16, 50),
#        datetime.time(16, 47), datetime.time(16, 45),
#        datetime.time(16, 48), datetime.time(16, 40),
#        datetime.time(16, 42), datetime.time(17, 30),
#        datetime.time(16, 35), datetime.time(16, 27, 4),
#        datetime.time(16, 29), datetime.time(16, 21, 21),
#        datetime.time(16, 18), datetime.time(16, 25),
#        datetime.time(16, 11, 15), datetime.time(16, 30),
#        datetime.time(16, 19), datetime.time(16, 14), datetime.time(16, 4),
#        datetime.time(17, 38), datetime.time(17, 35),
#        datetime.time(16, 32), datetime.time(16, 20),
#        datetime.time(16, 5, 54), datetime.time(16, 37),
#        datetime.time(16, 3), datetime.time(17, 57), datetime.time(17, 8),
#        datetime.time(16, 10), datetime.time(16, 5), datetime.time(16, 8),
#        datetime.time(16, 56), datetime.time(15, 45),
#        datetime.time(15, 41, 43), datetime.time(15, 38),
#        datetime.time(15, 40), datetime.time(15, 37),
#        datetime.time(15, 34, 54), datetime.time(15, 31, 56),
#        datetime.time(15, 32), datetime.time(15, 27, 14),
#        datetime.time(15, 30), datetime.time(15, 22),
#        datetime.time(15, 8, 37), datetime.time(15, 15),
#        datetime.time(15, 10), datetime.time(15, 26),
#        datetime.time(15, 20), datetime.time(15, 4), datetime.time(15, 35),
#        datetime.time(15, 3, 44), datetime.time(15, 0),
#        datetime.time(15, 3), datetime.time(14, 48, 51),
#        datetime.time(14, 47), datetime.time(14, 45),
#        datetime.time(14, 41), datetime.time(14, 44),
#        datetime.time(14, 37), datetime.time(14, 33),
#        datetime.time(14, 36), datetime.time(14, 30),
#        datetime.time(14, 23), datetime.time(14, 26),
#        datetime.time(15, 14), datetime.time(14, 11, 50),
#        datetime.time(14, 17), datetime.time(14, 18), datetime.time(15, 5),
#        datetime.time(13, 52, 35), datetime.time(13, 51),
#        datetime.time(14, 0), datetime.time(13, 52), datetime.time(13, 48),
#        datetime.time(13, 50), datetime.time(14, 28),
#        datetime.time(13, 55), datetime.time(13, 45),
#        datetime.time(13, 35), datetime.time(13, 40), datetime.time(14, 6),
#        datetime.time(13, 42), datetime.time(13, 32, 2),
#        datetime.time(14, 1), datetime.time(14, 40), datetime.time(13, 25),
#        datetime.time(13, 28), datetime.time(13, 24),
#        datetime.time(13, 26), datetime.time(13, 17, 54),
#        datetime.time(13, 27), datetime.time(13, 20),
#        datetime.time(13, 15), datetime.time(13, 12),
#        datetime.time(14, 55), datetime.time(13, 6, 26),
#        datetime.time(13, 10), datetime.time(13, 18),
#        datetime.time(14, 16), datetime.time(14, 50),
#        datetime.time(13, 11), datetime.time(14, 52),
#        datetime.time(15, 32, 42), datetime.time(14, 8),
#        datetime.time(15, 33), datetime.time(13, 30),
#        datetime.time(13, 29), datetime.time(13, 33), datetime.time(13, 7),
#        datetime.time(13, 8), datetime.time(14, 32), datetime.time(14, 20),
#        datetime.time(12, 0), datetime.time(11, 50), datetime.time(11, 57),
#        datetime.time(11, 35), datetime.time(11, 40),
#        datetime.time(11, 47), datetime.time(11, 32),
#        datetime.time(11, 30), datetime.time(11, 20),
#        datetime.time(11, 23), datetime.time(11, 12), datetime.time(11, 6),
#        datetime.time(11, 7), datetime.time(10, 54), datetime.time(11, 4),
#        datetime.time(10, 42), datetime.time(10, 58),
#        datetime.time(10, 36), datetime.time(10, 45),
#        datetime.time(11, 10), datetime.time(10, 38), datetime.time(11, 5),
#        datetime.time(10, 30), datetime.time(10, 27),
#        datetime.time(10, 18), datetime.time(11, 2), datetime.time(10, 15),
#        datetime.time(10, 50), datetime.time(11, 18), datetime.time(10, 2),
#        datetime.time(10, 52), datetime.time(10, 0), datetime.time(10, 26),
#        datetime.time(11, 0), datetime.time(10, 20), datetime.time(10, 8),
#        datetime.time(11, 45), datetime.time(10, 23),
#        datetime.time(10, 10), datetime.time(9, 51), datetime.time(9, 55),
#        datetime.time(11, 26), datetime.time(10, 4), datetime.time(10, 11),
#        datetime.time(11, 29), datetime.time(11, 11),
#        datetime.time(11, 15), datetime.time(10, 17), datetime.time(9, 58),
#        datetime.time(9, 30), datetime.time(9, 10), datetime.time(9, 17),
#        datetime.time(9, 0), datetime.time(8, 42), datetime.time(8, 50),
#        datetime.time(8, 45), datetime.time(8, 55), datetime.time(8, 28),
#        datetime.time(8, 18), datetime.time(8, 30), datetime.time(8, 36),
#        datetime.time(8, 15), datetime.time(8, 10), datetime.time(9, 18),
#        datetime.time(8, 11), datetime.time(9, 5), datetime.time(8, 35),
#        datetime.time(9, 15), datetime.time(8, 20), datetime.time(8, 5),
#        datetime.time(9, 20), datetime.time(9, 27), datetime.time(17, 53),
#        datetime.time(17, 48), datetime.time(18, 10),
#        datetime.time(17, 50), datetime.time(17, 23),
#        datetime.time(17, 20), datetime.time(17, 12),
#        datetime.time(17, 19), datetime.time(17, 34), datetime.time(17, 3),
#        datetime.time(16, 55), datetime.time(17, 26),
#        datetime.time(16, 46), datetime.time(16, 23),
#        datetime.time(16, 34), datetime.time(17, 4), datetime.time(16, 38),
#        datetime.time(16, 26), datetime.time(16, 15),
#        datetime.time(17, 52), datetime.time(16, 31), datetime.time(17, 9),
#        datetime.time(16, 16), datetime.time(17, 10, 7),
#        datetime.time(16, 0), datetime.time(15, 42), datetime.time(15, 25),
#        datetime.time(15, 19), datetime.time(15, 1), datetime.time(15, 52),
#        datetime.time(14, 48), datetime.time(14, 43),
#        datetime.time(14, 59), datetime.time(15, 7), datetime.time(14, 38),
#        datetime.time(14, 35), datetime.time(14, 10), datetime.time(14, 5),
#        datetime.time(14, 13), datetime.time(14, 7), datetime.time(15, 13),
#        datetime.time(14, 15), datetime.time(13, 9),
#        datetime.time(14, 49, 5), datetime.time(13, 5),
#        datetime.time(14, 54), datetime.time(13, 17),
#        datetime.time(14, 12), datetime.time(12, 15),
#        datetime.time(11, 43), datetime.time(11, 48),
#        datetime.time(11, 46), datetime.time(11, 31),
#        datetime.time(11, 22), datetime.time(10, 55),
#        datetime.time(10, 48), datetime.time(11, 49),
#        datetime.time(11, 44), datetime.time(10, 40),
#        datetime.time(11, 16), datetime.time(11, 58), datetime.time(10, 7),
#        datetime.time(11, 52), datetime.time(11, 28),
#        datetime.time(10, 21), datetime.time(9, 50), datetime.time(11, 42),
#        datetime.time(10, 47), datetime.time(10, 34),
#        datetime.time(10, 32), datetime.time(10, 25), datetime.time(10, 5),
#        datetime.time(11, 19), datetime.time(10, 22), datetime.time(9, 28),
#        datetime.time(9, 21), datetime.time(9, 23), datetime.time(9, 12),
#        datetime.time(9, 1), datetime.time(9, 25), datetime.time(8, 57),
#        datetime.time(8, 44), datetime.time(8, 40), datetime.time(9, 4),
#        datetime.time(8, 25), datetime.time(8, 9), datetime.time(8, 52),
#        datetime.time(8, 56), datetime.time(8, 21), datetime.time(8, 24),
#        datetime.time(17, 32), datetime.time(17, 14),
#        datetime.time(16, 35, 18), datetime.time(16, 57),
#        datetime.time(16, 32, 20), datetime.time(16, 27, 15),
#        datetime.time(16, 21, 31), datetime.time(16, 33),
#        datetime.time(16, 28), datetime.time(16, 13, 51),
#        datetime.time(16, 11), datetime.time(16, 13),
#        datetime.time(16, 12), datetime.time(15, 36), datetime.time(15, 8),
#        datetime.time(14, 57, 45), datetime.time(15, 2),
#        datetime.time(14, 56), datetime.time(14, 42),
#        datetime.time(14, 22), datetime.time(14, 9), datetime.time(14, 25),
#        datetime.time(13, 49, 21), datetime.time(14, 11),
#        datetime.time(13, 41, 5), datetime.time(13, 47),
#        datetime.time(14, 4), datetime.time(13, 32), datetime.time(15, 29),
#        datetime.time(13, 16), datetime.time(13, 44),
#        datetime.time(13, 57), datetime.time(13, 4), datetime.time(14, 39),
#        datetime.time(15, 44), datetime.time(14, 21),
#        datetime.time(11, 59, 33), datetime.time(11, 52, 12),
#        datetime.time(11, 43, 51), datetime.time(11, 38),
#        datetime.time(11, 35, 37), datetime.time(11, 55),
#        datetime.time(11, 27, 44), datetime.time(11, 22, 30),
#        datetime.time(11, 25), datetime.time(11, 24),
#        datetime.time(11, 3, 33), datetime.time(12, 5),
#        datetime.time(10, 59), datetime.time(11, 1), datetime.time(10, 53),
#        datetime.time(10, 27, 27), datetime.time(10, 23, 58),
#        datetime.time(10, 20, 55), datetime.time(10, 13),
#        datetime.time(10, 29), datetime.time(11, 3), datetime.time(10, 6),
#        datetime.time(10, 6, 14), datetime.time(10, 16),
#        datetime.time(9, 56), datetime.time(9, 23, 6),
#        datetime.time(9, 24), datetime.time(8, 59), datetime.time(9, 45),
#        datetime.time(8, 49, 12), datetime.time(8, 47),
#        datetime.time(8, 32, 45), datetime.time(8, 34),
#        datetime.time(8, 46), datetime.time(8, 19), datetime.time(8, 41),
#        datetime.time(8, 26), datetime.time(9, 8), datetime.time(9, 53),
#        datetime.time(8, 48), datetime.time(8, 22), datetime.time(9, 2),
#        datetime.time(17, 52, 29), datetime.time(17, 36, 7),
#        datetime.time(17, 22, 54), datetime.time(17, 31),
#        datetime.time(17, 18, 11), datetime.time(17, 28),
#        datetime.time(17, 51), datetime.time(16, 53, 37),
#        datetime.time(16, 46, 10), datetime.time(16, 44, 5),
#        datetime.time(16, 59), datetime.time(16, 43),
#        datetime.time(16, 41, 1), datetime.time(16, 36),
#        datetime.time(17, 27), datetime.time(16, 53),
#        datetime.time(16, 27), datetime.time(16, 2), datetime.time(16, 17),
#        datetime.time(16, 7), datetime.time(16, 44),
#        datetime.time(15, 36, 33), datetime.time(15, 34),
#        datetime.time(15, 30, 32), datetime.time(15, 41),
#        datetime.time(15, 21), datetime.time(15, 20, 58),
#        datetime.time(15, 18), datetime.time(15, 16),
#        datetime.time(14, 58, 43), datetime.time(14, 52, 36),
#        datetime.time(14, 53), datetime.time(14, 47, 34),
#        datetime.time(15, 23), datetime.time(15, 24),
#        datetime.time(14, 35, 53), datetime.time(14, 24, 57),
#        datetime.time(14, 57), datetime.time(13, 54, 37),
#        datetime.time(13, 47, 29), datetime.time(13, 58),
#        datetime.time(13, 31), datetime.time(13, 35, 36),
#        datetime.time(15, 3, 31), datetime.time(13, 37),
#        datetime.time(11, 17), datetime.time(10, 51),
#        datetime.time(10, 24), datetime.time(10, 43),
#        datetime.time(11, 13), datetime.time(10, 35), datetime.time(9, 54),
#        datetime.time(10, 37), datetime.time(9, 52), datetime.time(9, 14),
#        datetime.time(19, 14), datetime.time(9, 19), datetime.time(9, 13),
#        datetime.time(8, 54), datetime.time(8, 31), datetime.time(8, 8),
#        datetime.time(9, 6), datetime.time(9, 11), datetime.time(8, 13),
#        datetime.time(9, 16), datetime.time(9, 7), datetime.time(8, 53),
#        datetime.time(9, 11, 8), datetime.time(8, 16), datetime.time(8, 6),
#        datetime.time(17, 41), datetime.time(17, 37),
#        datetime.time(17, 39), datetime.time(17, 36),
#        datetime.time(17, 8, 18), datetime.time(18, 5),
#        datetime.time(17, 54), datetime.time(17, 6),
#        datetime.time(16, 59, 12), datetime.time(16, 46, 32),
#        datetime.time(16, 52), datetime.time(16, 31, 40),
#        datetime.time(16, 24), datetime.time(16, 21, 18),
#        datetime.time(16, 41), datetime.time(16, 1), datetime.time(16, 22),
#        datetime.time(16, 6), datetime.time(16, 4, 13),
#        datetime.time(15, 47, 6), datetime.time(15, 16, 13),
#        datetime.time(15, 0, 40), datetime.time(15, 12),
#        datetime.time(14, 36, 24), datetime.time(14, 27),
#        datetime.time(14, 25, 25), datetime.time(15, 6),
#        datetime.time(14, 18, 16), datetime.time(14, 34),
#        datetime.time(13, 44, 30), datetime.time(13, 41),
#        datetime.time(14, 58), datetime.time(13, 38),
#        datetime.time(13, 46), datetime.time(13, 21, 52),
#        datetime.time(13, 36), datetime.time(13, 3), datetime.time(14, 51),
#        datetime.time(13, 34), datetime.time(13, 1),
#        datetime.time(15, 28, 12), datetime.time(11, 51),
#        datetime.time(11, 54), datetime.time(11, 27),
#        datetime.time(11, 25, 9), datetime.time(12, 10),
#        datetime.time(11, 10, 55), datetime.time(11, 4, 43),
#        datetime.time(10, 57), datetime.time(10, 57, 48),
#        datetime.time(10, 51, 52), datetime.time(10, 44),
#        datetime.time(10, 41), datetime.time(10, 37, 41),
#        datetime.time(11, 41), datetime.time(10, 12, 52),
#        datetime.time(10, 3, 29), datetime.time(9, 59),
#        datetime.time(10, 28), datetime.time(9, 48), datetime.time(9, 46),
#        datetime.time(9, 59, 39), datetime.time(8, 58),
#        datetime.time(8, 37), datetime.time(9, 3), datetime.time(8, 14),
#        datetime.time(8, 27), datetime.time(9, 26), datetime.time(8, 12),
#        datetime.time(17, 44), datetime.time(17, 47),
#        datetime.time(17, 43), datetime.time(17, 33, 41),
#        datetime.time(17, 17), datetime.time(17, 13),
#        datetime.time(17, 3, 59), datetime.time(16, 59, 51),
#        datetime.time(16, 54), datetime.time(17, 2),
#        datetime.time(16, 42, 42), datetime.time(16, 34, 7),
#        datetime.time(16, 29, 26), datetime.time(16, 20, 48),
#        datetime.time(16, 9, 43), datetime.time(16, 9),
#        datetime.time(15, 39, 35), datetime.time(15, 36, 7),
#        datetime.time(14, 31), datetime.time(14, 2), datetime.time(13, 56),
#        datetime.time(13, 41, 43), datetime.time(13, 30, 48),
#        datetime.time(13, 26, 55), datetime.time(13, 21, 16),
#        datetime.time(13, 53), datetime.time(13, 15, 23),
#        datetime.time(13, 13), datetime.time(13, 54),
#        datetime.time(11, 59, 28), datetime.time(11, 54, 39),
#        datetime.time(11, 45, 40), datetime.time(11, 33),
#        datetime.time(11, 14), datetime.time(11, 12, 48),
#        datetime.time(10, 33), datetime.time(11, 36), datetime.time(10, 3),
#        datetime.time(9, 57), datetime.time(10, 9), datetime.time(8, 39),
#        datetime.time(8, 51), datetime.time(9, 20, 23),
#        datetime.time(8, 23), datetime.time(8, 4), datetime.time(8, 38),
#        datetime.time(17, 11), datetime.time(16, 21),
#        datetime.time(15, 39), datetime.time(15, 30, 27),
#        datetime.time(15, 43), datetime.time(15, 11),
#        datetime.time(14, 37, 39), datetime.time(14, 46),
#        datetime.time(13, 43), datetime.time(13, 39),
#        datetime.time(13, 22), datetime.time(13, 14, 14),
#        datetime.time(13, 5, 27), datetime.time(13, 23),
#        datetime.time(11, 36, 56), datetime.time(11, 14, 20),
#        datetime.time(11, 8), datetime.time(10, 47, 15),
#        datetime.time(10, 46), datetime.time(9, 21, 1),
#        datetime.time(9, 15, 29), datetime.time(9, 8, 42),
#        datetime.time(8, 53, 23), datetime.time(8, 33),
#        datetime.time(9, 30, 59), datetime.time(8, 7),
#        datetime.time(16, 29, 51), datetime.time(16, 23, 59),
#        datetime.time(16, 14, 23), datetime.time(15, 42, 15),
#        datetime.time(15, 36, 55), datetime.time(15, 27, 12),
#        datetime.time(15, 20, 27), datetime.time(13, 53, 7),
#        datetime.time(13, 41, 33), datetime.time(13, 31, 9),
#        datetime.time(13, 19, 55), datetime.time(13, 19),
#        datetime.time(13, 8, 58), datetime.time(11, 53, 46),
#        datetime.time(11, 42, 20), datetime.time(11, 23, 42),
#        datetime.time(11, 11, 18), datetime.time(11, 1, 3),
#        datetime.time(10, 53, 11), datetime.time(10, 50, 12),
#        datetime.time(11, 9), datetime.time(10, 23, 6),
#        datetime.time(10, 1, 5), datetime.time(9, 52, 36),
#        datetime.time(11, 37), datetime.time(9, 28, 58),
#        datetime.time(9, 25, 8), datetime.time(9, 16, 55),
#        datetime.time(9, 8, 12), datetime.time(8, 43),
#        datetime.time(8, 32), datetime.time(8, 11, 45),
#        datetime.time(10, 19), datetime.time(7, 16),
#        datetime.time(17, 52, 9), datetime.time(17, 46),
#        datetime.time(17, 17, 24), datetime.time(17, 18),
#        datetime.time(17, 8, 56), datetime.time(17, 2, 47),
#        datetime.time(16, 56, 41), datetime.time(17, 22),
#        datetime.time(16, 44, 53), datetime.time(16, 38, 4),
#        datetime.time(16, 30, 30), datetime.time(16, 13, 56),
#        datetime.time(16, 10, 57), datetime.time(16, 39),
#        datetime.time(15, 31, 34), datetime.time(15, 27, 22),
#        datetime.time(15, 21, 5), datetime.time(15, 18, 36),
#        datetime.time(15, 13, 22), datetime.time(15, 10, 3),
#        datetime.time(15, 7, 50), datetime.time(15, 1, 47),
#        datetime.time(15, 31), datetime.time(14, 29), datetime.time(14, 3),
#        datetime.time(11, 59), datetime.time(11, 34),
#        datetime.time(10, 31), datetime.time(9, 49), datetime.time(11, 56),
#        datetime.time(10, 34, 56), datetime.time(8, 14, 19),
#        datetime.time(9, 9), datetime.time(8, 23, 53),
#        datetime.time(17, 46, 6), datetime.time(17, 30, 50),
#        datetime.time(16, 26, 52), datetime.time(16, 16, 24),
#        datetime.time(16, 5, 31), datetime.time(15, 37, 16),
#        datetime.time(15, 24, 14), datetime.time(15, 5, 18),
#        datetime.time(14, 50, 1), datetime.time(14, 34, 40),
#        datetime.time(14, 7, 22), datetime.time(13, 57, 58),
#        datetime.time(13, 51, 18), datetime.time(13, 42, 36),
#        datetime.time(13, 6), datetime.time(10, 56), datetime.time(10, 49),
#        datetime.time(11, 21), datetime.time(8, 17), datetime.time(17, 29),
#        datetime.time(17, 24), datetime.time(15, 30, 41),
#        datetime.time(15, 17, 23), datetime.time(15, 9),
#        datetime.time(15, 5, 12), datetime.time(15, 2, 57),
#        datetime.time(15, 27), datetime.time(14, 47, 24),
#        datetime.time(14, 35, 29), datetime.time(14, 22, 46),
#        datetime.time(14, 20, 5), datetime.time(14, 11, 34),
#        datetime.time(13, 36, 55), datetime.time(13, 27, 32),
#        datetime.time(13, 21), datetime.time(13, 15, 1),
#        datetime.time(13, 5, 54), datetime.time(11, 51, 16),
#        datetime.time(11, 44, 53), datetime.time(10, 53, 26),
#        datetime.time(10, 17, 22), datetime.time(9, 27, 18),
#        datetime.time(9, 21, 28), datetime.time(9, 4, 37),
#        datetime.time(8, 50, 7), datetime.time(17, 33),
#        datetime.time(17, 59), datetime.time(15, 33, 52),
#        datetime.time(15, 28, 50), datetime.time(15, 9, 37),
#        datetime.time(15, 2, 52), datetime.time(14, 58, 29),
#        datetime.time(14, 52, 31), datetime.time(14, 47, 54),
#        datetime.time(14, 42, 45), datetime.time(14, 38, 24),
#        datetime.time(14, 34, 52), datetime.time(14, 29, 49),
#        datetime.time(14, 26, 19), datetime.time(13, 49),
#        datetime.time(14, 38, 26), datetime.time(13, 14),
#        datetime.time(13, 59), datetime.time(11, 8, 13),
#        datetime.time(10, 56, 58), datetime.time(10, 28, 7),
#        datetime.time(10, 14), datetime.time(10, 12),
#        datetime.time(9, 28, 21), datetime.time(9, 19, 18),
#        datetime.time(9, 5, 11), datetime.time(8, 46, 20),
#        datetime.time(16, 47, 54), datetime.time(16, 24, 59),
#        datetime.time(16, 18, 32), datetime.time(16, 13, 36),
#        datetime.time(16, 7, 15), datetime.time(15, 43, 42),
#        datetime.time(15, 37, 11), datetime.time(15, 34, 35),
#        datetime.time(15, 17, 43), datetime.time(15, 0, 47),
#        datetime.time(14, 44, 31), datetime.time(14, 27, 14),
#        datetime.time(13, 55, 30), datetime.time(13, 49, 6),
#        datetime.time(13, 46, 37), datetime.time(13, 43, 2),
#        datetime.time(13, 36, 36), datetime.time(11, 58, 1),
#        datetime.time(11, 53, 38), datetime.time(11, 39),
#        datetime.time(9, 58, 40), datetime.time(9, 51, 7),
#        datetime.time(10, 1), datetime.time(10, 39),
#        datetime.time(9, 22, 33), datetime.time(8, 49),
#        datetime.time(8, 1), datetime.time(8, 2), datetime.time(7, 45),
#        datetime.time(7, 30), datetime.time(6, 40), datetime.time(6, 30),
#        datetime.time(6, 20), datetime.time(6, 10), datetime.time(6, 3),
#        datetime.time(6, 0), datetime.time(7, 50), datetime.time(7, 22),
#        datetime.time(19, 0), datetime.time(18, 58), datetime.time(17, 56),
#        datetime.time(18, 38), datetime.time(17, 30, 46),
#        datetime.time(17, 19, 6), datetime.time(17, 12, 4),
#        datetime.time(17, 16), datetime.time(16, 58, 6),
#        datetime.time(16, 39, 39), datetime.time(17, 49),
#        datetime.time(16, 10, 16), datetime.time(15, 28, 59),
#        datetime.time(15, 24, 9), datetime.time(15, 21, 56),
#        datetime.time(15, 14, 33), datetime.time(14, 53, 24),
#        datetime.time(14, 39, 21), datetime.time(14, 17, 15),
#        datetime.time(14, 4, 14), datetime.time(13, 56, 35),
#        datetime.time(13, 52, 22), datetime.time(13, 48, 14),
#        datetime.time(14, 14), datetime.time(13, 42, 48),
#        datetime.time(14, 6, 59), datetime.time(9, 18, 26),
#        datetime.time(9, 22), datetime.time(9, 8, 10),
#        datetime.time(18, 20), datetime.time(17, 37, 53),
#        datetime.time(17, 30, 7), datetime.time(17, 8, 53),
#        datetime.time(16, 27, 54), datetime.time(16, 11, 3),
#        datetime.time(15, 36, 35), datetime.time(15, 29, 41),
#        datetime.time(15, 25, 58), datetime.time(15, 20, 44),
#        datetime.time(15, 17), datetime.time(15, 6, 21),
#        datetime.time(15, 4, 30), datetime.time(14, 59, 15),
#        datetime.time(14, 52, 53), datetime.time(14, 45, 58),
#        datetime.time(14, 42, 7), datetime.time(14, 24),
#        datetime.time(14, 19), datetime.time(11, 57, 54),
#        datetime.time(11, 53), datetime.time(11, 48, 59),
#        datetime.time(11, 46, 27), datetime.time(11, 42, 14),
#        datetime.time(11, 28, 30), datetime.time(11, 13, 52),
#        datetime.time(10, 59, 36), datetime.time(10, 41, 10),
#        datetime.time(8, 3), datetime.time(7, 25), datetime.time(7, 20),
#        datetime.time(6, 45), datetime.time(14, 50, 23),
#        datetime.time(14, 43, 48), datetime.time(14, 29, 58),
#        datetime.time(10, 36, 23), datetime.time(10, 21, 32),
#        datetime.time(10, 4, 54), datetime.time(9, 55, 22),
#        datetime.time(8, 23, 58), datetime.time(15, 59),
#        datetime.time(14, 1, 44), datetime.time(15, 39, 9),
#        datetime.time(6, 55), datetime.time(6, 50), datetime.time(17, 1),
#        datetime.time(17, 21), datetime.time(15, 49),
#        datetime.time(15, 28), datetime.time(14, 49),
#        datetime.time(14, 1, 9), datetime.time(9, 29),
#        datetime.time(16, 50, 49), datetime.time(16, 28, 2),
#        datetime.time(16, 10, 10), datetime.time(13, 51, 19),
#        datetime.time(13, 34, 9), datetime.time(13, 6, 41),
#        datetime.time(11, 56, 38), datetime.time(11, 38, 48),
#        datetime.time(10, 45, 37), datetime.time(10, 15, 48),
#        datetime.time(11, 11, 11), datetime.time(10, 30, 17),
#        datetime.time(9, 21, 44), datetime.time(9, 15, 28),
#        datetime.time(6, 57), datetime.time(11, 29, 33),
#        datetime.time(7, 5), datetime.time(6, 5), datetime.time(16, 51),
#        datetime.time(18, 0, 38), datetime.time(16, 49, 36),
#        datetime.time(13, 34, 54), datetime.time(15, 44, 28),
#        datetime.time(7, 15), datetime.time(7, 0), datetime.time(13, 2),
#        datetime.time(8, 25, 7), datetime.time(7, 38),
#        datetime.time(7, 27), nan], dtype=object)

# %%
dadosParada['total_horas'].unique()
# Out:
# array([5.00000e-02, 8.00000e-02, 2.30000e-01, 2.50000e-01, 3.30000e-01,
#        3.70000e-01, 1.50000e-01, 4.20000e-01, 7.00000e-02, 5.00000e-01,
#        1.70000e-01, 5.80000e-01, 7.50000e-01, 4.70000e-01, 8.70000e-01,
#        8.80000e-01, 1.20000e-01, 1.00000e+00, 3.00000e-02, 1.03000e+00,
#        1.17000e+00, 9.20000e-01, 1.20000e+00, 1.12000e+00, 3.80000e-01,
#        1.25000e+00, 1.23000e+00, 1.80000e-01, 1.42000e+00, 2.70000e-01,
#        1.30000e-01, 2.00000e-01, 1.15000e+00, 1.68000e+00, 5.30000e-01,
#        2.00000e-02, 9.50000e-01, 1.95000e+00, 1.58000e+00, 1.53000e+00,
#        7.80000e-01, 4.80000e-01, 4.50000e-01, 2.80000e-01, 2.00000e+00,
#        6.20000e-01, 1.13000e+00, 1.50000e+00, 8.30000e-01, 9.30000e-01,
#        2.20000e-01, 4.00000e-01, 1.00000e-01, 9.70000e-01, 3.00000e-01,
AUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL EXP',
#        'FINALIZACAO DE O.S.',
#        'RESOL. DE PROBLEMAS EM O.P. - DEFEITO INTERNO',
#        'REGISTRO DO APONTAMENTO NO SISTEMA', 'TROCA DE O.S.',
#        'NECESSIDADES OU ASSUNTOS PESSOAIS', 'FALTA DE MATÉRIA PRIMA',
#        'PROBLEMA RELACIONADO A SAÚDE PESSOAL OU DE COLEGA',
#        'PROCESSO ANTERIOR NÃO CONCLUÍDO',
#        'ATENDIMENTO AO BALCAO INTERNO - ALMOXARIFADO',
#        'PROCESSO PRODUÇÃO ESPECÍFICO - NÃO CALCULA PRODUTI',
#        'AGUARDANDO PROCESSO DE INSPEÇÃO DA QUALIDADE',
#        'CONFERÊNCIA DE MATÉRIA PRIMA NA O.P.', 'REUNIÃO',
#        'RESOL. DE PROBLEMAS EM O.P. - DEFEITO EXTERNO',
#        'NÃO CONFORMIDADE', 'FALTA DE ENERGIA', nan,
#        'ALTERAÇÃO DO PROJETO DO PRODUTO'], dtype=object)

# %%
dadosParada['cod_maquina'].unique()
# Out:
# array([14., nan,  5., 11.,  6., 15., 20.,  3.,  2., 16., 25.,  1., 12.,
#        17., 23.,  4., 24., 26., 22., 10.,  8.,  7.])

# %%
dadosParada['maquina'].unique()
# Out:
# array(['ORGANIZACAO E LIMPEZA', nan, 'MONITORAMENTO DE PROCESSO INTERNO',
#        'REGISTROS DE RNC DE O.P. ENCERRADA',
#        'SERVIÇOS PARA OUTROS SETORES', 'TREINAMENTO',
#        'REUNIÃO DE FEEDBACK/ ALINHAMENTOS',
#        'TEMPO OCIOSO (SEM ATIVIDADE)', 'EMBALAGEM',
#        'GRAVAÇÃO DE MICROCONTROLADOR',
#        'APONTAMENTO NO GESTOR DE SERVIÇO AVULSO', 'RESINA',
#        'PARADA PARA REUNIÃO',
#        'INSPEÇÃO DE PROCESSO / CONTROLE DE QUALIDADE',
#        'ATRASO POR FALTA DE FERRAMENTA', 'SERVIÇOS PARA O RICARDO',
#        'RESOLUÇÃO DE PROBLEMA DE MATERIAL DE TERCEIRO', 'DESCONSIDERAR',
#        'CONSERTO DE GIGAS OU FERRAMENTAS', 'INFRAESTRUTURA TECNNIC',
#        'SOLICITAÇÃO/ELABORAÇÃO DE PROCEDIMENTO', 'GIGA DE TESTE/GABARITO'],
#       dtype=object)

# %%
dadosParada['cod_operador'].unique()
# Out:
# array([180., 121., 150., 200., 199., 202.,  36.,  93., 183., 218., 159.,
#         53., 128., 156., 115., 133., 103.,  73., 210., 161., 198., 204.,
#        106., 215., 171., 126., 220.,  76.,  60., 179., 175., 147., 163.,
#        155., 122., 120., 189., 197., 201., 216., 151., 212., 213., 214.,
#        139., 207., 172., 195., 219.,  72., 141., 209.,  46., 217.,  52.,
#         69.,  77., 112.,  57.,   3.,  12.,  67., 186., 176.,  16.,  88.,
#        222., 223.,  nan])

# %%
dadosParada['cod_servico'].unique()
# Out:
# array([nan,  1.,  5.,  9.,  4.,  2.,  3.,  6., 10., 14., 11., 13.])

# %%
dadosParada['servico'].unique()
# Out:
# array([nan, 'SEPARACAO', 'PRE-TESTE', 'FINALIZAÇÃO DE PRODUTO',
#        'PRODUÇÃO', 'MECÂNICA', 'PRE-PRODUCAO', 'TESTE', 'ACABAMENTOS',
#        'TESTE INTERMEDIARIO', 'CONFIGURACAO',
#        'RECEBIMENTO DE TERCEIRIZACAO'], dtype=object)

# %% [markdown]
# Como podemos perceber, a maioria das colunas apresentam NaN ou NaT, isso se dá porquê a ultima linha da base de dados não é um registro e sim uma linha informando o total de horas e com os demais campos vazios, para resolver isso iremos remover a esse registro através de um drop onde o capo data for NaT

# %%
dadosParada = dadosParada[(~pd.isnull(dadosParada['data']))]
dadosParada = dadosParada.reset_index(drop=True)

# %% [markdown]
# Agora com o código acima aplicado, boa parte das colunas com NaN foram removidas, mas ainda faltam alguns detalhes

# %% [markdown]
# ### Unindo Colunas
# Existem algumas colunas atípicas onde as duas se completam, como por exemplo produto e máquina (e seus respectivos campos de código), por isso iremos uni-las e cria um único campo de descrição e código para máquina e serviço.

# %%
dadosParada['cod_maquina'] = dadosParada['cod_maquina'].fillna(0).astype(int)
dadosParada['cod_produto'] = dadosParada['cod_produto'].fillna(0).astype(int)

# %%
dadosParada['cod_produto_maquina'] = dadosParada['cod_maquina'] + dadosParada['cod_produto']
dadosParada['cod_produto_maquina'] = dadosParada['cod_produto_maquina'].astype(str)

# %%
dadosParada['cod_produto_maquina'].unique() # Visualizamos como esta coluna ficou
# Out:
# array(['14', '4387', '5', '5751', '11', '6', '15', '5461', '4545', '7512',
#        '20', '6104', '4094', '6029', '6096', '5753', '7411', '7038',
#        '6036', '7228', '6258', '7324', '3', '7229', '5714', '6243',
#        '6735', '6459', '6975', '5545', '2', '7072', '7442', '5697',
#        '7447', '7438', '7134', '2129', '7081', '0', '4746', '5477',
#        '5527', '6966', '7441', '3771', '7368', '6792', '6067', '5730',
#        '5957', '5478', '6276', '4008', '3979', '3920', '6555', '16',
#        '5960', '5706', '4711', '25', '5707', '1', '4669', '6938', '7443',
#        '6251', '6825', '4506', '6828', '5601', '4915', '7137', '6793',
#        '6673', '12', '4670', '4049', '17', '6418', '3491', '4407', '23',
#        '4', '7091', '4929', '5769', '5771', '2964', '3265', '6043',
#        '3219', '4572', '4196', '4723', '7046', '24', '7376', '5767',
#        '5920', '4648', '6420', '6015', '7106', '6905', '6937', '26',
#        '6913', '6031', '6060', '7034', '2130', '6483', '522', '5546',
#        '5946', '6032', '6921', '6794', '22', '7377', '6790', '6299',
#        '4508', '6030', '5869', '4479', '7146', '575', '6095', '4093',
#        '5583', '7048', '3523', '2617', '6998', '6928', '4477', '6926',
#        '7517', '6256', '2131', '7158', '2065', '3742', '4542', '6927',
#        '7087', '6925', '3348', '5773', '3739', '3347', '3677', '5464',
#        '6090', '7172', '6573', '6495', '7171', '6066', '2537', '6593',
#        '6069', '6574', '4733', '7247', '7402', '2817', '6366', '5912',
#        '6780', '10', '6068', '7045', '6990', '7006', '6058', '5030',
#        '6388', '6595', '6297', '7070', '5788', '7241', '8', '6914',
#        '7435', '6782', '5930', '6778', '6499', '7', '6717', '7272',
#        '6497', '6498', '5966', '7136', '6817', '7414', '6242', '7115',
#        '6852', '6850', '6814', '6841', '3330', '48', '5845', '7097',
#        '4651', '7504', '5844', '4083', '6833', '6349', '6836', '2363',
#        '7509', '5852', '5536', '957', '6518', '6405', '6035', '7077',
#        '6496', '6034', '5347', '3743', '7505', '4828', '7088', '7086',
#        '6092', '6087', '6991', '4514', '2855', '6868', '6610', '6033',
#        '3695', '4105', '6597', '7363', '4071', '7071', '7104', '5486',
#        '5721', '4069', '5820', '5992', '5775', '5885', '6277', '6367',
#        '4070', '1298', '6065', '7135', '4068', '5085', '6989', '7541',
#        '7161', '7085', '5083', '4674', '4663', '6438', '5086', '6088',
#        '7566', '7513', '4966', '3772', '7276', '7017', '5778', '4963',
#        '6500', '7561', '5476', '7119', '5402', '7510', '7094', '7550',
#        '5274', '7552', '5019', '5182', '2803', '2631', '7052', '3667',
#        '7275', '4082', '7051'], dtype=object)

# %% [markdown]
# já unimos as colunas de código máquina com código produto, podemos agora unir as colunas maquina e serviço, pois assim como nos códigos, quando não há nada em máquina, tem valor no campo serviço, e futuramente podemos pesquisar essa coluna como um enum

# %%
dadosParada['servico'] = dadosParada['servico'].fillna('')
dadosParada['maquina'] = dadosParada['maquina'].fillna('')

# %%
dadosParada['servico_maquina'] = dadosParada['servico'] + dadosParada['maquina']

# %%
dadosParada['servico_maquina'].unique()
# Out:
# array(['ORGANIZACAO E LIMPEZA', 'SEPARACAO',
#        'MONITORAMENTO DE PROCESSO INTERNO',
#        'REGISTROS DE RNC DE O.P. ENCERRADA',
#        'SERVIÇOS PARA OUTROS SETORES', 'TREINAMENTO', 'PRE-TESTE',
#        'FINALIZAÇÃO DE PRODUTO', 'REUNIÃO DE FEEDBACK/ ALINHAMENTOS',
#        'PRODUÇÃO', 'MECÂNICA', 'PRE-PRODUCAO',
#        'TEMPO OCIOSO (SEM ATIVIDADE)', 'TESTE', 'EMBALAGEM', '',
#        'GRAVAÇÃO DE MICROCONTROLADOR', 'ACABAMENTOS',
#        'APONTAMENTO NO GESTOR DE SERVIÇO AVULSO', 'RESINA',
#        'PARADA PARA REUNIÃO',
#        'INSPEÇÃO DE PROCESSO / CONTROLE DE QUALIDADE',
#        'ATRASO POR FALTA DE FERRAMENTA', 'SERVIÇOS PARA O RICARDO',
#        'RESOLUÇÃO DE PROBLEMA DE MATERIAL DE TERCEIRO',
#        'TESTE INTERMEDIARIO', 'SEPARACAOEMBALAGEM', 'DESCONSIDERAR',
#        'CONSERTO DE GIGAS OU FERRAMENTAS',
#        'FINALIZAÇÃO DE PRODUTOEMBALAGEM', 'CONFIGURACAO',
#        'SEPARACAOTEMPO OCIOSO (SEM ATIVIDADE)', 'INFRAESTRUTURA TECNNIC',
#        'PRODUÇÃOTREINAMENTO', 'SOLICITAÇÃO/ELABORAÇÃO DE PROCEDIMENTO',
#        'GIGA DE TESTE/GABARITO', 'RECEBIMENTO DE TERCEIRIZACAO',
#        'TESTEINSPEÇÃO DE PROCESSO / CONTROLE DE QUALIDADE',
#        'PRODUÇÃOORGANIZACAO E LIMPEZA',
#        'PRE-PRODUCAOAPONTAMENTO NO GESTOR DE SERVIÇO AVULSO',
#        'PRODUÇÃOAPONTAMENTO NO GESTOR DE SERVIÇO AVULSO',
#        'MECÂNICAORGANIZACAO E LIMPEZA',
#        'SEPARACAOMONITORAMENTO DE PROCESSO INTERNO',
#        'PRE-PRODUCAOTREINAMENTO'], dtype=object)

# %% [markdown]
# Agora podemos excluir os campos que não são mais necessários: cod_maquina, cod_produto, maquina, cod_servico e servico

# %%
dadosParada = dadosParada.drop(columns=['cod_maquina', 'cod_produto', 'maquina', 'cod_servico', 'servico'])
dadosParada.head()
# Out:
#         data hora_inicio hora_termino  total_horas  numero_os  numero_op  \
# 0 2023-03-01    17:57:00     18:00:00         0.05        0.0        0.0
# 1 2023-03-01    17:55:00     18:00:00         0.08        0.0        0.0
# 2 2023-03-01    17:50:00     17:53:24         0.05   107378.0    19719.0
# 3 2023-03-01    17:46:00     18:00:00         0.23        0.0        0.0
# 4 2023-03-01    17:45:00     18:00:00         0.25        0.0        0.0
#
#    qtde_op  cod_parada                                             parada  \
# 0      0.0         4.0  PAUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL...
# 1      0.0         4.0  PAUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL...
# 2     50.0         9.0                                FINALIZACAO DE O.S.
# 3      0.0         9.0                                FINALIZACAO DE O.S.
# 4      0.0         9.0                                FINALIZACAO DE O.S.
#
#    cod_operador cod_produto_maquina        servico_maquina
# 0         180.0                  14  ORGANIZACAO E LIMPEZA
# 1         121.0                  14  ORGANIZACAO E LIMPEZA
# 2         150.0                4387              SEPARACAO
# 3         200.0                  14  ORGANIZACAO E LIMPEZA
# 4         199.0                  14  ORGANIZACAO E LIMPEZA

# %%
from datetime import datetime, date

# %%
dadosParada = dadosParada.drop(columns=['total_horas'])

# %%
dadosParada['total_minutos'] = 0

for i in range(len(dadosParada)):
    minute = (datetime.combine(date.today(), dadosParada['hora_termino'][i]) - datetime.combine(date.today(), dadosParada['hora_inicio'][i])).seconds / 60
    dadosParada['total_minutos'][i] = minute
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_36768\3389442329.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dadosParada['total_minutos'][i] = minute

# %%
dadosParada['total_minutos'] = dadosParada['total_minutos'].astype(int)

# %%
dadosParada['total_minutos'].unique()
# Out:
# array([  3,   5,  14,  15,  20,  22,   9,  25,   4,  30,  10,  35,  45,
#         28,  52,  53,   7,  60,   2,  62,  70,  55,  72,  67,  23,  75,
#         74,  11,  85,  16,   8,  12,  69, 101,  32,   1,  57, 117,  95,
#         92,  47,  29,  27,  17, 120,  37,  68,  90,  50,  56,  13,  24,
#          6,  58,  18,  65,  77,  79,  87,  66,  99, 105, 110, 114, 115,
#        125, 130, 135, 137,  38, 138,  34,  96, 145,  73, 150, 152, 108,
#         26, 165,  76,  86, 157, 112, 153,  33,  40, 100, 160,  80,  49,
#         78,  21,  89, 116, 118,  61, 132,  93,  19, 104,  82,  43,  54,
#         88,  42,  48,  63,  83,  39,  41,  64,  98,  31,  46,  51,  81,
#        155, 142, 109,  94,  71, 113, 122, 107, 102,  44,  91, 139, 123,
#        149, 164, 121,  36,  59, 124,  84, 144, 140, 171, 103, 601,   0,
#         97, 111, 148, 161, 136, 158, 159, 127, 133, 175, 134, 119, 151,
#        131, 129, 143, 126, 141, 163, 156, 106, 147, 362, 300, 154, 170,
#        185, 308, 180, 262, 128, 146, 207])

# %% [markdown]
# ### Formatando campos
# Alguns campos ao longo deste código já foram criados e formatados, porém alguns campos "originais" precisam ser formatados, como o campo de data e o campo de código

# %%
def organizeData(x):
  try:
    dia = str(x)[8:10]
    mes = str(x)[5:7]
    ano = str(x)[:4]
    return dia+'/'+mes+'/'+ano
  except:
    pass

# %%
dataFrameData = dadosParada['data']
dataFrameData = pd.DataFrame(dataFrameData)
dataFrameData = dataFrameData.applymap(organizeData)
dadosParada['data'] = dataFrameData['data']

# %%
dadosParada.head()
# Out:
#          data hora_inicio hora_termino  numero_os  numero_op  qtde_op  \
# 0  01/03/2023    17:57:00     18:00:00        0.0        0.0      0.0
# 1  01/03/2023    17:55:00     18:00:00        0.0        0.0      0.0
# 2  01/03/2023    17:50:00     17:53:24   107378.0    19719.0     50.0
# 3  01/03/2023    17:46:00     18:00:00        0.0        0.0      0.0
# 4  01/03/2023    17:45:00     18:00:00        0.0        0.0      0.0
#
#    cod_parada                                             parada  \
# 0         4.0  PAUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL...
# 1         4.0  PAUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL...
# 2         9.0                                FINALIZACAO DE O.S.
# 3         9.0                                FINALIZACAO DE O.S.
# 4         9.0                                FINALIZACAO DE O.S.
#
#    cod_operador cod_produto_maquina        servico_maquina  total_minutos
# 0         180.0                  14  ORGANIZACAO E LIMPEZA              3
# 1         121.0                  14  ORGANIZACAO E LIMPEZA              5
# 2         150.0                4387              SEPARACAO              3
# 3         200.0                  14  ORGANIZACAO E LIMPEZA             14
# 4         199.0                  14  ORGANIZACAO E LIMPEZA             15

# %%
dadosParada['numero_os'] = dadosParada['numero_os'].astype(int)
dadosParada['numero_op'] = dadosParada['numero_op'].astype(int)
dadosParada['qtde_op'] = dadosParada['qtde_op'].astype(int)
dadosParada['cod_operador'] = dadosParada['cod_operador'].astype(int)
dadosParada['cod_parada'] = dadosParada['cod_parada'].astype(int)

# %%
dadosParada = dadosParada[dadosParada['parada'] != 'PAUSA PARA HORÁRIO DE CAFÉ OU ALMOÇO, OU FINAL EXP']
dadosParada = dadosParada[dadosParada['parada'] != 'FINALIZACAO DE O.S.']
dadosParada = dadosParada[dadosParada['parada'] != 'ALTERAÇÃO DO PROJETO DO PRODUTO']
dadosParada = dadosParada[~dadosParada['parada'].isnull()]

dadosParada.count()
# Out:
# data                   3765
# hora_inicio            3765
# hora_termino           3765
# numero_os              3765
# numero_op              3765
# qtde_op                3765
# cod_parada             3765
# parada                 3765
# cod_operador           3765
# cod_produto_maquina    3765
# servico_maquina        3765
# total_minutos          3765
# dtype: int64

# %%
dadosParada.to_csv('../data/dados_limpos.csv', index=False)
